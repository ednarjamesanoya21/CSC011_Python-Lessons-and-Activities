# %% [markdown]
# A **list** is an ordered collection of values. The values that make up a list are called its **elements**, or its **items**. We will use the term element or item to mean the same thing.
#
# Lists are similar to strings, which are ordered collections of characters, except that the elements of a list can be of any type. Lists and strings — and other collections that maintain the order of their items — are called **sequences**.

# %% [markdown]
# # **List Values**

# %% [markdown]
# There are several ways to create a new list; the simplest is to enclose the elements in square brackets (`[` and `]`):

# %%
#a list of four integers
ps = [10, 20, 30, 40]

#a list of three strings
qs = ["spam", "bungee", "swallow"]

# %% [markdown]
# The elements of a list don’t have to be the same type. The following list contains a string, a float, an integer, and another list:

# %%
zs = ["hello", 2.0, 5, [10, 20,[30, 40]],[]]

# %%
my_list = zs[3]

# %%
zs[3][2][0]
# Out:
# 30

# %% [markdown]
# A list within another list is said to be **nested**.

# %% [markdown]
# A list with no elements is called an empty list, and is denoted `[]`.

# %% [markdown]
# We can assign list values to variables or pass lists as parameters to functions:

# %%
vocabulary = ["apple", "cheese", "dog"]
numbers = [17, 123]
an_empty_list = []
print(vocabulary, numbers, an_empty_list)
# Out:
# ['apple', 'cheese', 'dog'] [17, 123] []

# %% [markdown]
# # **Accessing elements**

# %% [markdown]
# The syntax for accessing the elements of a list is the same as the syntax for accessing the characters of a string — the index operator: `[]` (not to be confused with an empty list). The expression inside the brackets specifies the index. Remember that the indices start at 0:

# %%
numbers[1]
# Out:
# 17

# %% [markdown]
# Any expression evaluating to an integer can be used as an index:

# %%
numbers[9-8]

# %%
numbers[1.0]

# %% [markdown]
# If you try to access or assign to an element that does not exist, you get a runtime error:

# %%
numbers[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-3cc7ed5fe4f2> in <module>()
# ----> 1 numbers[2]
#
# IndexError: list index out of range

# %% [markdown]
# It is common to use a loop variable as a list index.

# %%
horsemen = ["war", "famine", "pestilence", "death"]

for i in [0, 1, 2, 3]:
    print(horsemen[i])
# Out:
# war
# famine
# pestilence
# death

# %%
i = 0
while(i < 4):
    print(horsemen[i])
    i = i + 1
# Out:
# war
# famine
# pestilence
# death

# %% [markdown]
# Each time through the loop, the variable `i` is used as an index into the list, printing the `i`‘th element. This pattern of computation is called a **list traversal**.

# %% [markdown]
# The above sample doesn’t need or use the index `i` for anything besides getting the items from the list, so this more direct version — where the `for` loop gets the items — might be preferred:

# %%
horsemen = ["war", "famine", "pestilence", "death"]

for h in horsemen:
    print(h)
# Out:
# war
# famine
# pestilence
# death

# %% [markdown]
# # **List length**

# %% [markdown]
# The function `len` returns the length of a list, which is equal to the number of its elements. If you are going to use an integer index to access the list, it is a good idea to use this value as the upper bound of a loop instead of a constant.
#
# That way, if the size of the list changes, you won’t have to go through the program changing all the loops; they will work correctly for any size list:

# %%
horsemen = ["war", "famine", "pestilence", "death"]

for i in range(len(horsemen)):
    print(horsemen[i])
# Out:
# war
# famine
# pestilence
# death

# %%
print(range(len(horsemen)))
# Out:
# range(0, 4)

# %% [markdown]
# The last time the body of the loop is executed, `i` is `len(horsemen) - 1`, which is the index of the last element.

# %%
len(["car makers", 1, ["Ford", "Toyota", "BMW"], [1, 2, 3]])
# Out:
# 4

# %% [markdown]
# # **List membership**

# %% [markdown]
# `in` and `not in` are Boolean operators that test membership in a sequence. We used them previously with strings, but they also work with lists and other sequences:

# %%
horsemen = ["war", "famine", "pestilence", "death"]
"pestilence" in horsemen
# Out:
# True

# %%
"debauchery" in horsemen
# Out:
# False

# %%
"debauchery" not in horsemen
# Out:
# True

# %% [markdown]
# Using this we can produce an elegant version of a nested loop program example below:

# %%
students = [
    ("John", ["CompSci", "Physics"]),
    ("Vusi", ["Maths", "CompSci", "Stats"]),
    ("Jess", ["CompSci", "Accounting", "Economics", "Management"]),
    ("Sarah", ["InfSys", "Physics", "Economics", "CommLaw"]),
    ("Zuki", ["Sociology", "Economics", "Law", "Stats", "Music"])]

# Count how many students are taking Physics
counter = 0
for (name, subjects) in students:
    if "Physics" in subjects:
        counter = counter + 1


print("The number of students taking Physics is", counter)
# Out:
# The number of students taking Physics is 2

# %% [markdown]
# # **List operations**

# %% [markdown]
# The `+` operator concatenates lists:

# %%
a = [1,2,3]
b = [4,5,6]
c = a + b
c
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
"hello " * 3
# Out:
# 'hello hello hello '

# %% [markdown]
# Similarly, the `*` operator repeats a list a given number of times:

# %%
[0] * 4
# Out:
# [0, 0, 0, 0]

# %%
[1, 2, 3] * 3 #repeats the list [1,2,3] three times
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# # **List slices**

# %% [markdown]
# The slice operations we saw previously with strings let us work with sublists:

# %%
a_list = ["a", "b", "c", "d", "e", "f"]
a_list[1:3]
# Out:
# ['b', 'c']

# %%
a_list[:4]
# Out:
# ['a', 'b', 'c', 'd']

# %%
a_list[3:]
# Out:
# ['d', 'e', 'f']

# %%
a_list[:]
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %% [markdown]
# # **Lists are mutable**

# %% [markdown]
# Unlike strings, lists are **mutable**, which means we can change their elements. Using the index operator on the left side of an assignment, we can update one of the elements:

# %%
fruit = ["banana", "apple", "quince"]
fruit[0] = "pear"
fruit[2] = "orange"
fruit
# Out:
# ['pear', 'apple', 'orange']

# %% [markdown]
# The bracket operator applied to a list can appear anywhere in an expression. When it appears on the left side of an assignment, it changes one of the elements in the list, so the first element of `fruit` has been changed from `"banana"` to `"pear"`, and the last from `"quince"` to `"orange"`. An assignment to an element of a list is called **item assignment**.
#
# Remember that item assignment does not work for strings.

# %%
my_string = "TEST"
my_string[2] = "X"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d1c072641a03> in <module>
#       1 my_string = "TEST"
# ----> 2 my_string[2] = "X"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# but it does for lists:

# %%
my_list = ["T", "E", "S", "T"]
my_list[2] = "X"
my_list
# Out:
# ['T', 'E', 'X', 'T']

# %% [markdown]
# With the slice operator we can update a whole sublist at once:

# %%
a_list = ["a", "b", "c", "d", "e", "f"]
a_list[1:3] = ["x", "y"]
a_list
# Out:
# ['a', 'x', 'y', 'd', 'e', 'f']

# %% [markdown]
# We can also remove elements from a list by assigning an empty list to them:

# %%
a_list = ["a", "b", "c", "d", "e", "f"]
a_list[1:3] = []
a_list
# Out:
# ['a', 'd', 'e', 'f']

# %% [markdown]
# And we can add elements to a list by squeezing them into an empty slice at the desired location:

# %%
a_list = ["a", "d", "f"]
a_list[1:1] = ["b", "c"]
a_list
# Out:
# ['a', 'b', 'c', 'd', 'f']

# %%
a_list[4:4] = ["e"]
a_list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %% [markdown]
# # **List deletion**

# %% [markdown]
# Using slices to delete list elements can be error-prone. Python provides an alternative that is more readable. The `del` statement removes an element from a list:

# %%
a = ["one", "two", "three"]
del a[1]
a
# Out:
# ['one', 'three']

# %% [markdown]
# As you might expect, del causes a runtime error if the index is out of range.
#
# You can also use `del` with a slice to delete a sublist:

# %%
a_list = ["a", "b", "c", "d", "e", "f"]
del a_list[1:5]
a_list
# Out:
# ['a', 'f']

# %% [markdown]
# # **Cloning lists**

# %% [markdown]
# If we want to modify a list and also keep a copy of the original, we need to be able to make a copy of the list itself, not just the reference. This process is sometimes called **cloning**, to avoid the ambiguity of the word copy.
#
# The easiest way to clone a list is to use the slice operator:

# %%
a = [1, 2, 3]
b = a
b[0] = 4
print(a)
print(b)
# Out:
# [4, 2, 3]
# [4, 2, 3]

# %% [markdown]
# Taking any slice of a creates a new list. In this case the slice happens to consist of the whole list. So now the relationship is like this:
#
# ![Screen Shot 2022-01-12 at 3.11.37 PM.png](data:image/png;base64,...)

# %% [markdown]
# Now we are free to make changes to `b` without worrying that we’ll inadvertently be changing `a`:

# %%
b[0] = 5
a
# Out:
# [1, 2, 3]

# %% [markdown]
# # **Lists and `for` loops**

# %% [markdown]
# The `for` loop also works with lists. The generalized syntax of a `for` loop is:

# %%
for VARIABLE in LIST:
    BODY

# %% [markdown]
# Example,

# %%
def show_friends(friends):
    for friend in friends:
        print(friend)

friends = ["Joe", "Zoe", "Brad", "Angelina", "Zuki", "Thandi", "Paris"]
show_friends(friends)
# Out:
# Joe
# Zoe
# Brad
# Angelina
# Zuki
# Thandi
# Paris

# %% [markdown]
# It almost reads like English: For (every) friend in (the list of) friends, print (the name of the) friend.

# %% [markdown]
# Any list expression can be used in a `for` loop:

# %%
def count_div_3(max):
    count = 0
    for number in range(max):
        if number % 3 == 0:
            count += 1
    return count

print(count_div_3(20))
# Out:
# 7

# %%
# Out:
# range(0, 20)

# %% [markdown]
# The example above prints all the multiples of 3 between 0 and 19.

# %% [markdown]
# The example below expresses enthusiasm for various fruits.

# %%
for fruit in ["banana", "apple", "quince"]:
    print("I like to eat " + fruit + "s!")

# %% [markdown]
# Since lists are mutable, we often want to traverse a list, changing each of its elements. The following squares all the numbers in the list `xs`:

# %%
def show_letter(a):
    #do computations on a here
    return a

def show(xs):
    for i in range(len(xs)):
        xs[i] = xs[i]**2
    return xs

xs = [10, 20, 30, 40, 50]
new_list = show(xs)
print(new_list)

#a = 'x'
#print(show_letter(a))
# Out:
# [100, 400, 900, 1600, 2500]

# %% [markdown]
# # **List as parameters**

# %% [markdown]
# Passing a list as an argument actually passes a reference to the list, not a copy or clone of the list. So parameter passing creates an alias for you: the caller has one variable referencing the list, and the called function has an alias, but there is only one underlying list object. For example, the function below takes a list as an argument and multiplies each element in the list by 2:

# %%
def show_val(val): #val = "fun"
    val = val + "ny"
    print(val)

a_val = "fun"
show_val(a_val)
print(a_val)
# Out:
# funny
# fun

# %%
def show_list(things): #things = [2, 5, 9]
    things[1] = 0
    print(things)

a_list = [2, 5, 9]
print("Before", a_list)
show_list(a_list)
print("After", a_list)
# Out:
# Before [2, 5, 9]
# [2, 0, 9]
# After [2, 0, 9]

# %%
def double_stuff(a_list):
    """ Overwrite each element in a_list with double its value. """
    for (idx, val) in enumerate(a_list):
        a_list[idx] = 2 * val

# %% [markdown]
# If we add the following onto our script:

# %%
things = [2, 5, 9]
double_stuff(things)
print(things)
# Out:
# [4, 10, 18]

# %% [markdown]
# In the function above, the parameter `a_list` and the variable `things` are aliases for the same object. So before any changes to the elements in the list, the state snapshot looks like this:
#
# ![Screen Shot 2022-01-12 at 3.21.15 PM.png](data:image/png;base64,...)

# %% [markdown]
# # **List methods**

# %% [markdown]
# The dot operator can also be used to access built-in methods of list objects. We’ll start with the most useful method for adding something onto the end of an existing list:

# %%
mylist = []
mylist.append(5)
mylist.append(27)
mylist.append(3)
mylist.append(12)
mylist
# Out:
# [5, 27, 3, 12]

# %% [markdown]
# `append` is a list method which adds the argument passed to it to the end of the list. We’ll use it heavily when we’re creating new lists. Continuing with this example, we show several other list methods:

# %%
mylist.insert(1, 12) # Insert 12 at pos 1, shift other items up
mylist
# Out:
# [5, 12, 27, 3, 12]

# %%
mylist.count(12) # How many times is 12 in mylist?

# %%
mylist.extend([5, 9, 5, 11])   # Put whole list onto end of mylist
mylist
# Out:
# [5, 12, 27, 3, 12, 5, 9, 5, 11, 5, 9, 5, 11]

# %%
mylist.index(9) # Find index of first 9 in mylist

# %%
mylist.reverse()
mylist
# Out:
# [11, 5, 9, 5, 11, 5, 9, 5, 12, 3, 27, 12, 5]

# %%
mylist.sort()
mylist
# Out:
# [3, 5, 5, 5, 5, 5, 9, 9, 11, 11, 12, 12, 27]

# %%
mylist.remove(12)
mylist
# Out:
# [3, 5, 5, 5, 5, 5, 9, 9, 11, 11, 12, 27]

# %% [markdown]
# Experiment and play with the list methods shown here, and read their documentation until you feel confident that you understand how they work.

# %% [markdown]
# # **Strings and lists**

# %% [markdown]
# Two of the most useful methods on strings involve conversion to and from lists of substrings. The `split` method breaks a string into a list of words. By default, any number of whitespace characters is considered a word boundary:

# %%
song = "The rain in Spain..."
wds = song.split()
wds
# Out:
# ['The', 'rain', 'in', 'Spain...']

# %% [markdown]
# An optional argument called a **delimiter** can be used to specify which string to use as the boundary marker between substrings. The following example uses the string `ai` as the delimiter:

# %%
song.split("ai")
# Out:
# ['The r', 'n in Sp', 'n...']

# %% [markdown]
# Notice that the delimiter doesn’t appear in the result.

# %% [markdown]
# The inverse of the `split` method is `join`. You choose a desired **separator** string, (often called the *glue*) and join the list with the glue between each of the elements:

# %%
glue = ";"
s = glue.join(wds)
s
# Out:
# 'The;rain;in;Spain...'

# %% [markdown]
# The list that you glue together (wds in this example) is not modified. Also, as these next examples show, you can use empty glue or multi-character strings as glue:

# %%
" --- ".join(wds)
# Out:
# 'The --- rain --- in --- Spain...'

# %%
"0".join(wds)
# Out:
# 'The0rain0in0Spain...'

# %% [markdown]
# Python has a built-in type conversion function called `list` that tries to turn whatever you give it into a list.

# %%
xs = list("Crunchy Frog")
xs
# Out:
# ['C', 'r', 'u', 'n', 'c', 'h', 'y', ' ', 'F', 'r', 'o', 'g']

# %%
"".join(xs)
# Out:
# 'Crunchy Frog'

# %% [markdown]
# # **Nested lists**

# %% [markdown]
# A nested list is a list that appears as an element in another list. In this list, the element with index 3 is a nested list:

# %%
nested = ["hello", 2.0, 5, [10, 20, [30, 40, [50, 60]]]]

# %% [markdown]
# If we output the element at index 3, we get:

# %%
print(nested[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-caa263afbc8e> in <module>()
# ----> 1 print(nested[3])
#
# NameError: name 'nested' is not defined

# %% [markdown]
# To extract an element from the nested list, we can proceed in two steps:

# %%
elem = nested[3]
elem[0]
# Out:
# 10

# %% [markdown]
# Or we can combine them:

# %%
nested[3][2]
# Out:
# [30, 40, [50, 60]]

# %% [markdown]
# Bracket operators evaluate from left to right, so this expression gets the 3’th element of nested and extracts the 1’th element from it.

# %% [markdown]
# # **Matrices**

# %% [markdown]
# Nested lists are often used to represent matrices. For example, the matrix:
#
# ![matrix2.png](data:image/png;base64,...)

# %% [markdown]
# might be represented as:

# %%
mx = [[1, 2, 3], [4, 5, 6], [7, 8, 9]] #mx[i][j] i -> 0, 1, 2  j -> 0, 1, 2
print(mx[2][2])
1 2 3
4 5 6
7 8 9
# Out:
# 9

# %%
def create_matrix(matrix)

def show_matrix(matrix)

# %% [markdown]
# `mx` is a list with three elements, where each element is a row of the matrix. We can select an entire row from the matrix in the usual way:

# %%
mx[1]
# Out:
# [4, 5, 6]

# %% [markdown]
# Or we can extract a single element from the matrix using the double-index form:

# %%
mx[1][1]
# Out:
# 5

# %% [markdown]
# The first index selects the row, and the second index selects the column. Although this way of representing matrices is common, it is not the only possibility.
